# %% [markdown]
# # Lecture 5 Notes: Introductions to Pandas

# %% [markdown]
# Pandas is a powerful and flexible Python library primarily used for data manipulation and analysis.
#
# To load the pandas package and start working with it, import the package. The community agreed alias for pandas is `pd`.

# %%
# import pandas using the alias pd

# %% [markdown]
# ### Pandas data table representation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example of pandas dataframe

# %%
df = pd.DataFrame(
    {
        "Name": [
            "Braund, Mr. Owen Harris",
            "Allen, Mr. William Henry",
            "Bonnell, Miss. Elizabeth",
        ],
        "Age": [22, 35, 58],
        "Sex": ["male", "male", "female"],
    }
)

df

# %% [markdown]
# This format is very similar to excel or other spreadsheet software <br><br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Each column in a DataFrame is a Series
# ![image.png](attachment:image.png)

# %%
# separate just the age column from the rest of the data

# %%
# print the type of the age column

# %% [markdown]
# ### Defining a pandas series
# ```python
# pd.Series(list, name="series_name")
# ```

# %%
# define a series from scratch

# %%
# get the maximum age using the max() function

# %% [markdown]
# ### Working with data files

# %%
# use pandas to load the data is genes.csv, and save the data to a variable called genes_df


# print the dataframe

# %%
# print the shape of the data

# %%
# print just the first three rows

# %%
# print just the last three rows

# %% [markdown]
# ### Filtering a dataframe
# ```python
# new_df = old_df[conditional statement]
# ```

# %%
# create a new dataframe called short_genes_df that only contains rows where the gene length is less than 300

# %%
# create a new dataframe called chromosome_10_df that only contains genes from chromosome 10

# %% [markdown]
# ### Looping over a dataframe

# %%
# loop over the rows in the dataframe using .iterrows() and print each row

# %%
# loop over the dataframe using .iterrows() and print the gene name and length for each row

# %% [markdown]
# ### Adding columns to a dataframe

# %%
expression_levels = [120.5, 80.3, 45.8, 200.1, 150.7, 95.4, 60.2, 175.5]

# add a new column to the dataframe called "Expression Level" and set it equal to expression_levels

# %%
# add a new column to the dataframe called "Expression Category"
# The values in this column should be True if the expression level is greater than 100, and False otherwise

# define a blank list to store the values
expression_categories = []

# loop over the expression levels

# %% [markdown]
# ### Sorting a dataframe
# ```python
# df.sort_values('column name', ascending=False)
# ```
#
# The 'ascending' key word arguement controls whether the sort is high-to-low or low-to-high.

# %%
# sort the dataframe by expression level, from highest to lowest

# %%
# sort the dataframe by gene length, from shortest to longest

# %% [markdown]
# ### Other useful pandas tools

# %%
# get a summary of the dataframe using .describe()

# %% [markdown]
# ### Saving a dataframe
# ```python
# df.to_csv('filename.csv')
# ```

# %%
# save the dataframe to a new file called "genes_with_expression.csv"

# %% [markdown]
# ### Additional Resources
# [Pandas Official Getting Started Guide](https://pandas.pydata.org/pandas-docs/stable/getting_started/index.html#getting-started)
#
# [YouTube Video on Pandas DataFrame and Series](https://www.youtube.com/watch?v=zmdjNSmRXF4&list=PL-osiE80TeTsWmV9i9c58mdDCSskIFdDS&index=2)
